# %%
import ml_cca

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_multilabel_classification

# %%
X, Y = make_multilabel_classification(n_features=1800000, n_classes=2, n_labels=1,
                                      allow_unlabeled=True,
                                      random_state=1)

# %%
def plot_result(X,Y):
    zero_class = np.where(Y[:, 0])
    one_class = np.where(Y[:, 1])
    plt.scatter(X[:, 0], X[:, 1], s=40, c='gray')
    plt.scatter(X[zero_class, 0], X[zero_class, 1], s=160, edgecolors='b',
                   facecolors='none', linewidths=2, label='Class 1')
    plt.scatter(X[one_class, 0], X[one_class, 1], s=80, edgecolors='orange',
                   facecolors='none', linewidths=2, label='Class 2')

# %%
plot_result(X,Y)

# %%
cca = ml_cca.MaximumLikelihoodCCA(2)

# %%
cca.fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-e661a3d946f2> in <module>()
# ----> 1 cca.fit(X,Y)
#
# /home/harrison/Documents/mri/ml_cca.py in fit(self, X, Y)
#     108             pca = PCA(n_components = 50000,whiten=True)
#     109             self.X = pca.fit_transform(self.X)
# --> 110             self.Y = pca.fit_transform(self.Y)
#     111             print self.X.shape
#     112             z = np.concatenate((self.X.T,self.Y.T)) #combine the tranposed data.
#
# /usr/local/lib/python2.7/dist-packages/sklearn/decomposition/pca.pyc in fit_transform(self, X, y)
#     318
#     319         """
# --> 320         U, S, V = self._fit(X)
#     321         U = U[:, :self.n_components_]
#     322
#
# /usr/local/lib/python2.7/dist-packages/sklearn/decomposition/pca.pyc in _fit(self, X)
#     355         # Call different fits for either full or truncated SVD
#     356         if svd_solver == 'full':
# --> 357             return self._fit_full(X, n_components)
#     358         elif svd_solver in ['arpack', 'randomized']:
#     359             return self._fit_truncated(X, n_components, svd_solver)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/decomposition/pca.pyc in _fit_full(self, X, n_components)
#     370             raise ValueError("n_components=%r must be between 0 and "
#     371                              "n_features=%r with svd_solver='full'"
# --> 372                              % (n_components, n_features))
#     373
#     374         # Center data
#
# ValueError: n_components=50000 must be between 0 and n_features=2 with svd_solver='full'

# %%
cca.transform()

# %%
plot_result(cca.E_z_xy,Y)

# %%
cca.var_z_xy
# Out:
# array([[ -9.56973716,   0.        ],
#        [  0.        , -11.06713116]])
